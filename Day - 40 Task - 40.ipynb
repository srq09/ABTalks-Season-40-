# %%
# !pip install pymongo python-dotenv openai numpy
# Out:
# ...
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/11/c0/c04da9f4c0c6252404598f4e394b862a58a9e866822a70ae261c8a018fdf/pymongo-4.17.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for dnspython<3.0.0,>=2.6.1 from https://files.pythonhosted.org/packages/ba/5a/18ad964b0086c6e62e2e7500f7edc89e3faa45033c71c1893d34eed2b2de/dnspython-2.8.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/867.9 kB ? eta -:--:--
#    - ------------------------------------- 30.7/867.9 kB 660.6 kB/s eta 0:00:02
#    --- ------------------------------------ 81.9/867.9 kB 1.2 MB/s eta 0:00:01
#    -------- ------------------------------- 194.6/867.9 kB 1.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 225.3/867.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 491.5/867.9 kB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 604.2/867.9 kB 2.4 MB/s eta 0:00:01
# ...

# %%
OPENAI_API_KEY= "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"

# %%
from pymongo import MongoClient
from dotenv import load_dotenv
import os

load_dotenv()

MONGODB_URI = os.getenv("MONGODB_URI")

client = MongoClient(MONGODB_URI)

db = client["ai_search_db"]

documents_collection = db["documents"]

print("MongoDB Connected Successfully")
# Out:
# MongoDB Connected Successfully

# %%
# !pip install pymongo sentence-transformers numpy torch

# %%
# Day-40: Store Metadata and Embeddings (Simulation)

documents = [
    {
        "title": "Introduction to AI",
        "metadata": {
            "author": "John Smith",
            "category": "AI"
        },
        "embedding": [0.12, 0.45, 0.78]
    },
    {
        "title": "MongoDB Basics",
        "metadata": {
            "author": "David Lee",
            "category": "Database"
        },
        "embedding": [0.23, 0.67, 0.34]
    },
    {
        "title": "Vector Databases",
        "metadata": {
            "author": "Sarah Wilson",
            "category": "AI"
        },
        "embedding": [0.89, 0.54, 0.11]
    }
]

print("=" * 50)
print("DOCUMENTS STORED SUCCESSFULLY")
print("=" * 50)

for doc in documents:
    print(f"Title: {doc['title']}")
    print(f"Author: {doc['metadata']['author']}")
    print(f"Category: {doc['metadata']['category']}")
    print(f"Embedding: {doc['embedding']}")
    print("-" * 50)

print("\nTask Day-40 Completed Successfully!")
# Out:
# ...
# DOCUMENTS STORED SUCCESSFULLY
# ...
# Title: Introduction to AI
# Author: John Smith
# Category: AI
# Embedding: [0.12, 0.45, 0.78]
# --------------------------------------------------
# Title: MongoDB Basics
# Author: David Lee
# Category: Database
# Embedding: [0.23, 0.67, 0.34]
# --------------------------------------------------
# Title: Vector Databases
# Author: Sarah Wilson
# Category: AI
# Embedding: [0.89, 0.54, 0.11]
# --------------------------------------------------
#
# Task Day-40 Completed Successfully!
